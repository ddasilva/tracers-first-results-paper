# %%
from datetime import timedelta
import pandas as pd
import numpy as np
import lib_dasilva2026
# Out:
# /home/dedasilv/micromamba/envs/tracers-dispersion-detection/lib/python3.11/site-packages/spacepy/time.py:2448: UserWarning: Leapseconds may be out of date. Use spacepy.toolbox.update(leapsecs=True)
#   _read_leaps()

# %%
def get_d(i):
    with open(f'output/dprime_{i}.txt', 'r') as fh:
        d = float(fh.read())
        print(f'd = {d:.2f}')
        return d

# %%
df = pd.read_csv('output/Sept30_Storm_filtered.csv', parse_dates=['start_time', 'end_time'], index_col=0)
df['i'] = np.arange(len(df))

# %% [markdown]
# # Event #0

# %%
row = df.iloc[0]

data = lib_dasilva2026.load_data(
    aci_file=row.aci_file,
    ead_file=row.ead_file,
)
subset_data = data.subset(row.start_time, row.end_time)
dispersion_stime = row.start_time
dispersion_etime = row.end_time - timedelta(seconds=25)

fig, (ax1, ax2) = subset_data.plot_recon_rate(
    dispersion_stime, 
    dispersion_etime, 
    d=get_d(row.i),
    data_file=f'output/recon_event{row.i}.csv',
)
# Out:
# d = 15.79
# Bs at satellite 44699.46130975912 nT
# Wrote to output/recon_event0.csv
# RR Max: 1.6678212980083071 mV / m
# /home/dedasilv/current_projects/tracers-first-results-paper/lib_dasilva2026.py:207: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(new_xticklabels)

# %% [markdown]
# # Event #1

# %%
row = df.iloc[1]

data = lib_dasilva2026.load_data(
    aci_file=row.aci_file,
    ead_file=row.ead_file,
)
subset_data = data.subset(row.start_time, row.end_time)
dispersion_stime = row.start_time
dispersion_etime = row.end_time - timedelta(seconds=25)

fig, (ax1, ax2) = subset_data.plot_recon_rate(
    dispersion_stime, 
    dispersion_etime, 
    d=get_d(row.i),
    data_file=f'output/recon_event{row.i}.csv',
)
# Out:
# d = 10.61
# Bs at satellite 44425.9465312508 nT
# Wrote to output/recon_event1.csv
# RR Max: 2.5781858621194784 mV / m
# /home/dedasilv/current_projects/tracers-first-results-paper/lib_dasilva2026.py:207: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(new_xticklabels)

# %% [markdown]
# # Event #2

# %%
row = df.iloc[2]

data = lib_dasilva2026.load_data(
    aci_file=row.aci_file,
    ead_file=row.ead_file,
)
subset_data = data.subset(row.start_time, row.end_time)
dispersion_stime = row.start_time + timedelta(seconds=20)
dispersion_etime = row.end_time - timedelta(seconds=25)

fig, (ax1, ax2) = subset_data.plot_recon_rate(
    dispersion_stime, 
    dispersion_etime, 
    d=get_d(row.i),
    data_file=f'output/recon_event{row.i}.csv',
)
# Out:
# d = 13.10
# Bs at satellite 45150.31320665458 nT
# Wrote to output/recon_event2.csv
# RR Max: 1.0751773185324054 mV / m
# /home/dedasilv/current_projects/tracers-first-results-paper/lib_dasilva2026.py:207: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(new_xticklabels)

# %% [markdown]
# # Event #3

# %%
row = df.iloc[3]

data = lib_dasilva2026.load_data(
    aci_file=row.aci_file,
    ead_file=row.ead_file,
)
subset_data = data.subset(row.start_time, row.end_time)
dispersion_stime = row.start_time + timedelta(seconds=32)
dispersion_etime = row.end_time - timedelta(seconds=20)

fig, (ax1, ax2) = subset_data.plot_recon_rate(
    dispersion_stime, 
    dispersion_etime, 
    d=get_d(row.i),
    data_file=f'output/recon_event{row.i}.csv',
)
# Out:
# d = 9.16
# Bs at satellite 44109.4454349713 nT
# Wrote to output/recon_event3.csv
# RR Max: 11.583649382348499 mV / m
# /home/dedasilv/current_projects/tracers-first-results-paper/lib_dasilva2026.py:207: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(new_xticklabels)

# %% [markdown]
# # Event #4

# %%
row = df.iloc[4]

data = lib_dasilva2026.load_data(
    aci_file=row.aci_file,
    ead_file=row.ead_file,
)
subset_data = data.subset(row.start_time, row.end_time)
dispersion_stime = row.start_time + timedelta(seconds=32)
dispersion_etime = row.end_time - timedelta(seconds=28)

fig, (ax1, ax2) = subset_data.plot_recon_rate(
    dispersion_stime, 
    dispersion_etime, 
    d=get_d(row.i),
    data_file=f'output/recon_event{row.i}.csv',
)
# Out:
# d = 14.76
# Bs at satellite 44249.246284467146 nT
# Wrote to output/recon_event4.csv
# RR Max: 1.8357104010923864 mV / m
# /home/dedasilv/current_projects/tracers-first-results-paper/lib_dasilva2026.py:207: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(new_xticklabels)

# %% [markdown]
# # Event #5

# %%
row = df.iloc[5]

data = lib_dasilva2026.load_data(
    aci_file=row.aci_file,
    ead_file=row.ead_file,
)
subset_data = data.subset(row.start_time, row.end_time)
dispersion_stime = row.start_time + timedelta(seconds=15)
dispersion_etime = row.end_time - timedelta(seconds=28)

fig, (ax1, ax2) = subset_data.plot_recon_rate(
    dispersion_stime, 
    dispersion_etime, 
    d=get_d(row.i),
    data_file=f'output/recon_event{row.i}.csv',
)
# Out:
# d = 14.52
# Bs at satellite 43696.28600471937 nT
# Wrote to output/recon_event5.csv
# RR Max: 0.7328319142099904 mV / m
# /home/dedasilv/current_projects/tracers-first-results-paper/lib_dasilva2026.py:207: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(new_xticklabels)

# %% [markdown]
# # Event #6

# %%
row = df.iloc[6]

data = lib_dasilva2026.load_data(
    aci_file=row.aci_file,
    ead_file=row.ead_file,
)
subset_data = data.subset(row.start_time, row.end_time)
dispersion_stime = row.start_time + timedelta(seconds=5)
dispersion_etime = row.end_time - timedelta(seconds=27)

fig, (ax1, ax2) = subset_data.plot_recon_rate(
    dispersion_stime, 
    dispersion_etime, 
    d=get_d(row.i),
    data_file=f'output/recon_event{row.i}.csv',
)
# Out:
# d = 15.78
# Bs at satellite 44455.50275266231 nT
# Wrote to output/recon_event6.csv
# RR Max: 1.0138529539264007 mV / m
# /home/dedasilv/current_projects/tracers-first-results-paper/lib_dasilva2026.py:207: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(new_xticklabels)

# %% [markdown]
# # Event #7

# %%
row = df.iloc[7]

data = lib_dasilva2026.load_data(
    aci_file=row.aci_file,
    ead_file=row.ead_file,
)
subset_data = data.subset(row.start_time, row.end_time)
dispersion_stime = row.start_time + timedelta(seconds=17)
dispersion_etime = row.end_time - timedelta(seconds=24)

fig, (ax1, ax2) = subset_data.plot_recon_rate(
    dispersion_stime, 
    dispersion_etime, 
    d=get_d(row.i),
    data_file=f'output/recon_event{row.i}.csv',
)
# Out:
# d = 22.64
# Bs at satellite 44427.82376191565 nT
# Wrote to output/recon_event7.csv
# RR Max: 1.1450241426121386 mV / m
# /home/dedasilv/current_projects/tracers-first-results-paper/lib_dasilva2026.py:207: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(new_xticklabels)

# %% [markdown]
# # Event #8

# %%
row = df.iloc[8]

data = lib_dasilva2026.load_data(
    aci_file=row.aci_file,
    ead_file=row.ead_file,
)
subset_data = data.subset(row.start_time, row.end_time)
dispersion_stime = row.start_time + timedelta(seconds=25)
dispersion_etime = row.end_time - timedelta(seconds=25)

fig, (ax1, ax2) = subset_data.plot_recon_rate(
    dispersion_stime, 
    dispersion_etime, 
    d=get_d(row.i),
    data_file=f'output/recon_event{row.i}.csv',
)
# Out:
# d = 14.28
# Bs at satellite 43049.643269862034 nT
# Wrote to output/recon_event8.csv
# RR Max: 1.1646965551765054 mV / m
# /home/dedasilv/current_projects/tracers-first-results-paper/lib_dasilva2026.py:207: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(new_xticklabels)

# %% [markdown]
# # Event #9

# %%
row = df.iloc[9]

data = lib_dasilva2026.load_data(
    aci_file=row.aci_file,
    ead_file=row.ead_file,
)
subset_data = data.subset(row.start_time, row.end_time)
dispersion_stime = row.start_time + timedelta(seconds=32)
dispersion_etime = row.end_time - timedelta(seconds=33)

fig, (ax1, ax2) = subset_data.plot_recon_rate(
    dispersion_stime, 
    dispersion_etime, 
    d=get_d(row.i),
    data_file=f'output/recon_event{row.i}.csv',
)
# Out:
# d = 14.55
# Bs at satellite 42984.030729319486 nT
# Wrote to output/recon_event9.csv
# RR Max: 11.434921140024969 mV / m
# /home/dedasilv/current_projects/tracers-first-results-paper/lib_dasilva2026.py:207: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(new_xticklabels)

# %% [markdown]
# # Event #10

# %%
row = df.iloc[10]

data = lib_dasilva2026.load_data(
    aci_file=row.aci_file,
    ead_file=row.ead_file,
)
subset_data = data.subset(row.start_time, row.end_time)
dispersion_stime = row.start_time + timedelta(seconds=32)
dispersion_etime = row.end_time - timedelta(seconds=29)

fig, (ax1, ax2) = subset_data.plot_recon_rate(
    dispersion_stime, 
    dispersion_etime, 
    d=get_d(row.i),
    data_file=f'output/recon_event{row.i}.csv',
)
# Out:
# d = 12.82
# Bs at satellite 44333.744401935386 nT
# Wrote to output/recon_event10.csv
# RR Max: 1.4168377387817779 mV / m
# /home/dedasilv/current_projects/tracers-first-results-paper/lib_dasilva2026.py:207: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(new_xticklabels)

# %% [markdown]
# # Event #11

# %%
row = df.iloc[11]

data = lib_dasilva2026.load_data(
    aci_file=row.aci_file,
    ead_file=row.ead_file,
)
subset_data = data.subset(row.start_time, row.end_time)
dispersion_stime = row.start_time + timedelta(seconds=32)
dispersion_etime = row.end_time - timedelta(seconds=30)

fig, (ax1, ax2) = subset_data.plot_recon_rate(
    dispersion_stime, 
    dispersion_etime, 
    d=get_d(row.i),
    data_file=f'output/recon_event{row.i}.csv',
)
# Out:
# d = 13.76
# Bs at satellite 45082.88125518224 nT
# Wrote to output/recon_event11.csv
# RR Max: 1.5342062377417143 mV / m
# /home/dedasilv/current_projects/tracers-first-results-paper/lib_dasilva2026.py:207: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(new_xticklabels)

# %% [markdown]
# # Event #12

# %%
row = df.iloc[12]

data = lib_dasilva2026.load_data(
    aci_file=row.aci_file,
    ead_file=row.ead_file,
)
subset_data = data.subset(row.start_time, row.end_time)
dispersion_stime = row.start_time + timedelta(seconds=32)
dispersion_etime = row.end_time - timedelta(seconds=23)

fig, (ax1, ax2) = subset_data.plot_recon_rate(
    dispersion_stime, 
    dispersion_etime, 
    d=get_d(row.i),
    data_file=f'output/recon_event{row.i}.csv',
)
# Out:
# d = 17.21
# Bs at satellite 44402.451411712216 nT
# Wrote to output/recon_event12.csv
# RR Max: 11.622059077221582 mV / m
# /home/dedasilv/current_projects/tracers-first-results-paper/lib_dasilva2026.py:207: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(new_xticklabels)

# %% [markdown]
# # Event #13

# %%
row = df.iloc[13]

data = lib_dasilva2026.load_data(
    aci_file=row.aci_file,
    ead_file=row.ead_file,
)
subset_data = data.subset(row.start_time, row.end_time)
dispersion_stime = row.start_time + timedelta(seconds=25)
dispersion_etime = row.end_time - timedelta(seconds=32)

fig, (ax1, ax2) = subset_data.plot_recon_rate(
    dispersion_stime, 
    dispersion_etime, 
    d=get_d(row.i),
    data_file=f'output/recon_event{row.i}.csv',
)
# Out:
# d = 16.84
# Bs at satellite 43987.20579846889 nT
# Wrote to output/recon_event13.csv
# RR Max: 0.8427154451317145 mV / m
# /home/dedasilv/current_projects/tracers-first-results-paper/lib_dasilva2026.py:207: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(new_xticklabels)

# %% [markdown]
# # Event #14

# %%
row = df.iloc[14]

data = lib_dasilva2026.load_data(
    aci_file=row.aci_file,
    ead_file=row.ead_file,
)
subset_data = data.subset(row.start_time, row.end_time)
dispersion_stime = row.start_time + timedelta(seconds=5)
dispersion_etime = row.end_time - timedelta(seconds=30)

fig, (ax1, ax2) = subset_data.plot_recon_rate(
    dispersion_stime, 
    dispersion_etime, 
    d=get_d(row.i),
    data_file=f'output/recon_event{row.i}.csv',
)
# Out:
# d = 18.41
# Bs at satellite 43793.27584595034 nT
# Wrote to output/recon_event14.csv
# RR Max: 0.9301361063858322 mV / m
# /home/dedasilv/current_projects/tracers-first-results-paper/lib_dasilva2026.py:207: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(new_xticklabels)

# %% [markdown]
# # Event #15

# %%
row = df.iloc[15]

data = lib_dasilva2026.load_data(
    aci_file=row.aci_file,
    ead_file=row.ead_file,
)
subset_data = data.subset(row.start_time, row.end_time)
dispersion_stime = row.start_time + timedelta(seconds=15)
dispersion_etime = row.end_time - timedelta(seconds=30)

fig, (ax1, ax2) = subset_data.plot_recon_rate(
    dispersion_stime, 
    dispersion_etime, 
    d=get_d(row.i),
    data_file=f'output/recon_event{row.i}.csv',
)
# Out:
# d = 15.68
# Bs at satellite 43786.51881785687 nT
# Wrote to output/recon_event15.csv
# RR Max: 11.54116936206729 mV / m
# /home/dedasilv/current_projects/tracers-first-results-paper/lib_dasilva2026.py:207: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(new_xticklabels)

# %% [markdown]
# # Event #16

# %%
row = df.iloc[16]

data = lib_dasilva2026.load_data(
    aci_file=row.aci_file,
    ead_file=row.ead_file,
)
subset_data = data.subset(row.start_time, row.end_time)
dispersion_stime = row.start_time + timedelta(seconds=32)
dispersion_etime = row.end_time - timedelta(seconds=30)

fig, (ax1, ax2) = subset_data.plot_recon_rate(
    dispersion_stime, 
    dispersion_etime, 
    d=get_d(row.i),
    data_file=f'output/recon_event{row.i}.csv',
)
# Out:
# d = 15.74
# Bs at satellite 43536.84212240909 nT
# Wrote to output/recon_event16.csv
# RR Max: 0.7920834298135941 mV / m
# /home/dedasilv/current_projects/tracers-first-results-paper/lib_dasilva2026.py:207: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(new_xticklabels)

# %% [markdown]
# # Event #17

# %%
row = df.iloc[17]

data = lib_dasilva2026.load_data(
    aci_file=row.aci_file,
    ead_file=row.ead_file,
)
subset_data = data.subset(row.start_time, row.end_time)
dispersion_stime = row.start_time + timedelta(seconds=5)
dispersion_etime = row.end_time - timedelta(seconds=30)

fig, (ax1, ax2) = subset_data.plot_recon_rate(
    dispersion_stime, 
    dispersion_etime, 
    d=get_d(row.i),
    data_file=f'output/recon_event{row.i}.csv',
)
# Out:
# d = 13.72
# Bs at satellite 44332.10828898892 nT
# Wrote to output/recon_event17.csv
# RR Max: 0.7534688432463684 mV / m
# /home/dedasilv/current_projects/tracers-first-results-paper/lib_dasilva2026.py:207: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(new_xticklabels)

# %% [markdown]
# # Event #18

# %%
row = df.iloc[18]

data = lib_dasilva2026.load_data(
    aci_file=row.aci_file,
    ead_file=row.ead_file,
)
subset_data = data.subset(row.start_time, row.end_time)
dispersion_stime = row.start_time + timedelta(seconds=32)
dispersion_etime = row.end_time - timedelta(seconds=30)

fig, (ax1, ax2) = subset_data.plot_recon_rate(
    dispersion_stime, 
    dispersion_etime, 
    d=get_d(row.i),
    data_file=f'output/recon_event{row.i}.csv',
)
# Out:
# d = 12.30
# Bs at satellite 44591.11339230543 nT
# Wrote to output/recon_event18.csv
# RR Max: 11.64672344221297 mV / m
# /home/dedasilv/current_projects/tracers-first-results-paper/lib_dasilva2026.py:207: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(new_xticklabels)

# %% [markdown]
# # Event #19

# %%
row = df.iloc[10]

data = lib_dasilva2026.load_data(
    aci_file=row.aci_file,
    ead_file=row.ead_file,
)
subset_data = data.subset(row.start_time, row.end_time)
dispersion_stime = row.start_time + timedelta(seconds=32)
dispersion_etime = row.end_time - timedelta(seconds=31)

fig, (ax1, ax2) = subset_data.plot_recon_rate(
    dispersion_stime, 
    dispersion_etime, 
    d=get_d(row.i),
    data_file=f'output/recon_event{row.i}.csv',
)
# Out:
# d = 12.82
# Bs at satellite 44339.650077771425 nT
# Wrote to output/recon_event10.csv
# RR Max: 0.9860748054409897 mV / m
# /home/dedasilv/current_projects/tracers-first-results-paper/lib_dasilva2026.py:207: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(new_xticklabels)

# %% [markdown]
# # Event #20

# %%
row = df.iloc[20]

data = lib_dasilva2026.load_data(
    aci_file=row.aci_file,
    ead_file=row.ead_file,
)
subset_data = data.subset(row.start_time, row.end_time)
dispersion_stime = row.start_time + timedelta(seconds=25)
dispersion_etime = row.end_time - timedelta(seconds=25)

fig, (ax1, ax2) = subset_data.plot_recon_rate(
    dispersion_stime, 
    dispersion_etime, 
    d=get_d(row.i),
    data_file=f'output/recon_event{row.i}.csv',
)
# Out:
# d = 14.99
# Bs at satellite 44363.97642665801 nT
# Wrote to output/recon_event20.csv
# RR Max: 0.4735822000531887 mV / m
# /home/dedasilv/current_projects/tracers-first-results-paper/lib_dasilva2026.py:207: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(new_xticklabels)
