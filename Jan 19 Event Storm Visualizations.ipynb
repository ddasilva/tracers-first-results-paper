# %%
start_time = "2026-01-19T00:00:00"
end_time = "2026-01-26T00:00:00"
storm = "Jan19_Storm"
title = 'Jan 19, 2025 Storm'

# %%
import lib_stormvis

# %%
lib_stormvis.make_storm_vis(storm, start_time, end_time, title,
                           hl={0: ('red', 'Figure 7: Event #1'), 
                               1: ('orange', 'Figure 8: Event #2')})
# Out:
# SYM-H Minimum: -257
