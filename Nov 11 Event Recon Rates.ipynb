# %%
from datetime import timedelta
import pandas as pd
import numpy as np
import lib_dasilva2026
# Out:
# /home/dedasilv/micromamba/envs/tracers-dispersion-detection/lib/python3.11/site-packages/spacepy/time.py:2448: UserWarning: Leapseconds may be out of date. Use spacepy.toolbox.update(leapsecs=True)
#   _read_leaps()

# %%
storm = 'Nov11_Storm'

# %%
def get_d(i):
    return 15
    with open(f'output/{storm}/dprime_{i}.txt', 'r') as fh:
        d = float(fh.read())
        print(f'd = {d:.2f}')
        return d

# %%
df = pd.read_csv(f'output/{storm}_filtered.csv', parse_dates=['start_time', 'end_time'], index_col=0)
df['i'] = np.arange(len(df))

# %%
print(len(df))
# Out:
# 6

# %% [markdown]
# # Event #0

# %%
row = df.iloc[0]

data = lib_dasilva2026.load_data(
    aci_file=row.aci_file,
    ead_file=row.ead_file,
)
subset_data = data.subset(row.start_time, row.end_time)
dispersion_stime = row.start_time + timedelta(seconds=25)
dispersion_etime = row.end_time - timedelta(seconds=25)

fig, (ax1, ax2) = subset_data.plot_recon_rate(
    dispersion_stime, 
    dispersion_etime, 
    d=get_d(row.i),
    data_file=f'output/{storm}/recon_event{row.i}.csv',
    ascending=False,
)
# Out:
# Bs at satellite 44407.08272437005 nT
# Wrote to output/Nov11_Storm/recon_event0.csv
# RR Max: 1.7331397164948432 mV / m
# /home/dedasilv/current_projects/tracers-first-results-paper/lib_dasilva2026.py:209: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(new_xticklabels)

# %% [markdown]
# # Event #1

# %%
row = df.iloc[1]

data = lib_dasilva2026.load_data(
    aci_file=row.aci_file,
    ead_file=row.ead_file,
)
subset_data = data.subset(row.start_time, row.end_time)
dispersion_stime = row.start_time + timedelta(seconds=19)
dispersion_etime = row.end_time - timedelta(seconds=26)

fig, (ax1, ax2) = subset_data.plot_recon_rate(
    dispersion_stime, 
    dispersion_etime, 
    d=get_d(row.i),
    data_file=f'output/{storm}/recon_event{row.i}.csv',
    ascending=False,
)
# Out:
# Bs at satellite 43705.81487552038 nT
# Wrote to output/Nov11_Storm/recon_event1.csv
# RR Max: 2.9693737882000697 mV / m
# /home/dedasilv/current_projects/tracers-first-results-paper/lib_dasilva2026.py:209: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(new_xticklabels)

# %% [markdown]
# # Event #2

# %%
row = df.iloc[2]

data = lib_dasilva2026.load_data(
    aci_file=row.aci_file,
    ead_file=row.ead_file,
)
subset_data = data.subset(row.start_time, row.end_time)
dispersion_stime = row.start_time + timedelta(seconds=14)
dispersion_etime = row.end_time - timedelta(seconds=26)

fig, (ax1, ax2) = subset_data.plot_recon_rate(
    dispersion_stime, 
    dispersion_etime, 
    d=get_d(row.i),
    data_file=f'output/{storm}/recon_event{row.i}.csv',
    ascending=False,
)
# Out:
# Bs at satellite 43241.86638270511 nT
# Wrote to output/Nov11_Storm/recon_event2.csv
# RR Max: 1.2002304848737988 mV / m
# /home/dedasilv/current_projects/tracers-first-results-paper/lib_dasilva2026.py:209: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(new_xticklabels)

# %% [markdown]
# # Event #3

# %%
row = df.iloc[3]

data = lib_dasilva2026.load_data(
    aci_file=row.aci_file,
    ead_file=row.ead_file,
)
subset_data = data.subset(row.start_time, row.end_time)
dispersion_stime = row.start_time + timedelta(seconds=20)
dispersion_etime = row.end_time - timedelta(seconds=26)

fig, (ax1, ax2) = subset_data.plot_recon_rate(
    dispersion_stime, 
    dispersion_etime, 
    d=get_d(row.i),
    data_file=f'output/{storm}/recon_event{row.i}.csv',
    ascending=False,
)
# Out:
# Bs at satellite 43639.469540271486 nT
# Wrote to output/Nov11_Storm/recon_event3.csv
# RR Max: 8.64114507916382 mV / m
# /home/dedasilv/current_projects/tracers-first-results-paper/lib_dasilva2026.py:209: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(new_xticklabels)

# %% [markdown]
# # Event #4

# %%
row = df.iloc[4]

data = lib_dasilva2026.load_data(
    aci_file=row.aci_file,
    ead_file=row.ead_file,
)
subset_data = data.subset(row.start_time, row.end_time)
dispersion_stime = row.start_time + timedelta(seconds=20)
dispersion_etime = row.end_time - timedelta(seconds=26)

fig, (ax1, ax2) = subset_data.plot_recon_rate(
    dispersion_stime, 
    dispersion_etime, 
    d=get_d(row.i),
    data_file=f'output/{storm}/recon_event{row.i}.csv',
    ascending=False,
)
# Out:
# Bs at satellite 43599.41906056149 nT
# Wrote to output/Nov11_Storm/recon_event4.csv
# RR Max: 3.052016876980792 mV / m
# /home/dedasilv/current_projects/tracers-first-results-paper/lib_dasilva2026.py:209: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(new_xticklabels)

# %% [markdown]
# # Event #5

# %%
row = df.iloc[5]

data = lib_dasilva2026.load_data(
    aci_file=row.aci_file,
    ead_file=row.ead_file,
)
subset_data = data.subset(row.start_time, row.end_time)
dispersion_stime = row.start_time + timedelta(seconds=42)
dispersion_etime = row.end_time - timedelta(seconds=20)

fig, (ax1, ax2) = subset_data.plot_recon_rate(
    dispersion_stime, 
    dispersion_etime, 
    d=get_d(row.i),
    data_file=f'output/{storm}/recon_event{row.i}.csv',
    ascending=False,
)
# Out:
# Bs at satellite 43903.632424316216 nT
# Wrote to output/Nov11_Storm/recon_event5.csv
# RR Max: 1.0644709219699555 mV / m
# /home/dedasilv/current_projects/tracers-first-results-paper/lib_dasilva2026.py:209: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(new_xticklabels)
