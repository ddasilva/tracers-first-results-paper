# %%
start_time = "2025-11-10T12:00:00"
end_time = "2025-11-16T00:00:00"
storm = "Nov11_Storm"
title = 'Nov 11, 2025 Storm'

# %%
import lib_stormvis

# %%
lib_stormvis.make_storm_vis(storm, start_time, end_time, title, no_cpcp=True)
