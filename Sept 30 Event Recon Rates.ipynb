# %%
from datetime import timedelta
import pandas as pd
import numpy as np
import lib_dasilva2026

# %%
def get_d(i):
    with open(f'output/Sept30_Storm/dprime_{i}.txt', 'r') as fh:
        d = float(fh.read())
        print(f'd = {d:.2f}')
        return d

# %%
df = pd.read_csv('output/Sept30_Storm_filtered.csv', parse_dates=['start_time', 'end_time'], index_col=0)
df['i'] = np.arange(len(df))

# %% [markdown]
# # Event #0

# %%
row = df.iloc[0]

data = lib_dasilva2026.load_data(
    aci_file=row.aci_file,
    ead_file=row.ead_file,
)
subset_data = data.subset(row.start_time, row.end_time)
dispersion_stime = row.start_time
dispersion_etime = row.end_time - timedelta(seconds=25)

fig, (ax1, ax2) = subset_data.plot_recon_rate(
    dispersion_stime, 
    dispersion_etime, 
    d=get_d(row.i),
    data_file=f'output/Sept30_Storm/recon_event{row.i}.csv',
)
# Out:
# d = 15.79
# Bs at satellite 44699.46130975912 nT
# Wrote to output/Sept30_Storm/recon_event0.csv
# RR Max: 1.9081867971761937 mV / m
# /home/ubuntu/tracers-work/tracers-first-results-paper/lib_dasilva2026.py:209: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(new_xticklabels)

# %% [markdown]
# # Event #1

# %%
row = df.iloc[1]

data = lib_dasilva2026.load_data(
    aci_file=row.aci_file,
    ead_file=row.ead_file,
)
subset_data = data.subset(row.start_time, row.end_time)
dispersion_stime = row.start_time
dispersion_etime = row.end_time - timedelta(seconds=25)

fig, (ax1, ax2) = subset_data.plot_recon_rate(
    dispersion_stime, 
    dispersion_etime, 
    d=get_d(row.i),
    data_file=f'output/Sept30_Storm/{row.i}.csv',
)
# Out:
# d = 10.61
# Bs at satellite 44425.9465312508 nT
# Wrote to output/Sept30_Storm/1.csv
# RR Max: 2.514941097865505 mV / m
# /home/ubuntu/tracers-work/tracers-first-results-paper/lib_dasilva2026.py:209: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(new_xticklabels)

# %% [markdown]
# # Event #2

# %%
row = df.iloc[2]

data = lib_dasilva2026.load_data(
    aci_file=row.aci_file,
    ead_file=row.ead_file,
)
subset_data = data.subset(row.start_time, row.end_time)
dispersion_stime = row.start_time + timedelta(seconds=20)
dispersion_etime = row.end_time - timedelta(seconds=25)

fig, (ax1, ax2) = subset_data.plot_recon_rate(
    dispersion_stime, 
    dispersion_etime, 
    d=get_d(row.i),
    data_file=f'output/Sept30_Storm/recon_event{row.i}.csv',
)
# Out:
# d = 13.10
# Bs at satellite 45150.31320665458 nT
# Wrote to output/Sept30_Storm/recon_event2.csv
# RR Max: 1.9602841346731497 mV / m
# /home/ubuntu/tracers-work/tracers-first-results-paper/lib_dasilva2026.py:209: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(new_xticklabels)

# %% [markdown]
# # Event #3

# %%
row = df.iloc[3]

data = lib_dasilva2026.load_data(
    aci_file=row.aci_file,
    ead_file=row.ead_file,
)
subset_data = data.subset(row.start_time, row.end_time)
dispersion_stime = row.start_time + timedelta(seconds=32)
dispersion_etime = row.end_time - timedelta(seconds=17)

fig, (ax1, ax2) = subset_data.plot_recon_rate(
    dispersion_stime, 
    dispersion_etime, 
    d=get_d(row.i),
    data_file=f'output/Sept30_Storm/recon_event{row.i}.csv',
)
# Out:
# d = 9.16
# Bs at satellite 44099.84681020771 nT
# Wrote to output/Sept30_Storm/recon_event3.csv
# RR Max: 4.0145334711891385 mV / m
# /home/ubuntu/tracers-work/tracers-first-results-paper/lib_dasilva2026.py:209: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(new_xticklabels)

# %% [markdown]
# # Event #4

# %%
row = df.iloc[4]

data = lib_dasilva2026.load_data(
    aci_file=row.aci_file,
    ead_file=row.ead_file,
)
subset_data = data.subset(row.start_time, row.end_time)
dispersion_stime = row.start_time + timedelta(seconds=32)
dispersion_etime = row.end_time - timedelta(seconds=28)

fig, (ax1, ax2) = subset_data.plot_recon_rate(
    dispersion_stime, 
    dispersion_etime, 
    d=get_d(row.i),
    data_file=f'output/Sept30_Storm/recon_event{row.i}.csv',
)
# Out:
# d = 14.76
# Bs at satellite 44249.246284467146 nT
# Wrote to output/Sept30_Storm/recon_event4.csv
# RR Max: 2.0080608649808895 mV / m
# /home/ubuntu/tracers-work/tracers-first-results-paper/lib_dasilva2026.py:209: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(new_xticklabels)

# %% [markdown]
# # Event #5

# %%
row = df.iloc[5]

data = lib_dasilva2026.load_data(
    aci_file=row.aci_file,
    ead_file=row.ead_file,
)
subset_data = data.subset(row.start_time, row.end_time)
dispersion_stime = row.start_time + timedelta(seconds=15)
dispersion_etime = row.end_time - timedelta(seconds=28)

fig, (ax1, ax2) = subset_data.plot_recon_rate(
    dispersion_stime, 
    dispersion_etime, 
    d=get_d(row.i),
    data_file=f'output/Sept30_Storm/recon_event{row.i}.csv',
)
# Out:
# d = 14.52
# Bs at satellite 43696.28600471937 nT
# Wrote to output/Sept30_Storm/recon_event5.csv
# RR Max: 1.1539809770152782 mV / m
# /home/ubuntu/tracers-work/tracers-first-results-paper/lib_dasilva2026.py:209: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(new_xticklabels)

# %% [markdown]
# # Event #6

# %%
row = df.iloc[6]

data = lib_dasilva2026.load_data(
    aci_file=row.aci_file,
    ead_file=row.ead_file,
)
subset_data = data.subset(row.start_time, row.end_time)
dispersion_stime = row.start_time + timedelta(seconds=5)
dispersion_etime = row.end_time - timedelta(seconds=27)

fig, (ax1, ax2) = subset_data.plot_recon_rate(
    dispersion_stime, 
    dispersion_etime, 
    d=get_d(row.i),
    data_file=f'output/Sept30_Storm/recon_event{row.i}.csv',
)
# Out:
# d = 15.78
# Bs at satellite 44455.50275266231 nT
# Wrote to output/Sept30_Storm/recon_event6.csv
# RR Max: 1.0723262887427725 mV / m
# /home/ubuntu/tracers-work/tracers-first-results-paper/lib_dasilva2026.py:209: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(new_xticklabels)

# %% [markdown]
# # Event #7

# %%
row = df.iloc[7]

data = lib_dasilva2026.load_data(
    aci_file=row.aci_file,
    ead_file=row.ead_file,
)
subset_data = data.subset(row.start_time, row.end_time)
dispersion_stime = row.start_time + timedelta(seconds=17)
dispersion_etime = row.end_time - timedelta(seconds=24)

fig, (ax1, ax2) = subset_data.plot_recon_rate(
    dispersion_stime, 
    dispersion_etime, 
    d=get_d(row.i),
    data_file=f'output/Sept30_Storm/recon_event{row.i}.csv',
)
# Out:
# d = 22.64
# Bs at satellite 44427.82376191565 nT
# Wrote to output/Sept30_Storm/recon_event7.csv
# RR Max: 1.7470680105017642 mV / m
# /home/ubuntu/tracers-work/tracers-first-results-paper/lib_dasilva2026.py:209: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(new_xticklabels)

# %% [markdown]
# # Event #8

# %%
row = df.iloc[8]

data = lib_dasilva2026.load_data(
    aci_file=row.aci_file,
    ead_file=row.ead_file,
)
subset_data = data.subset(row.start_time, row.end_time)
dispersion_stime = row.start_time + timedelta(seconds=25)
dispersion_etime = row.end_time - timedelta(seconds=25)

fig, (ax1, ax2) = subset_data.plot_recon_rate(
    dispersion_stime, 
    dispersion_etime, 
    d=get_d(row.i),
    data_file=f'output/Sept30_Storm/recon_event{row.i}.csv',
)
# Out:
# d = 14.28
# Bs at satellite 43049.643269862034 nT
# Wrote to output/Sept30_Storm/recon_event8.csv
# RR Max: 1.2381813517741684 mV / m
# /home/ubuntu/tracers-work/tracers-first-results-paper/lib_dasilva2026.py:209: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(new_xticklabels)

# %% [markdown]
# # Event #9

# %%
row = df.iloc[9]

data = lib_dasilva2026.load_data(
    aci_file=row.aci_file,
    ead_file=row.ead_file,
)
subset_data = data.subset(row.start_time, row.end_time)
dispersion_stime = row.start_time + timedelta(seconds=32)
dispersion_etime = row.end_time - timedelta(seconds=33)

fig, (ax1, ax2) = subset_data.plot_recon_rate(
    dispersion_stime, 
    dispersion_etime, 
    d=get_d(row.i),
    data_file=f'output/Sept30_Storm/recon_event{row.i}.csv',
)
# Out:
# d = 14.55
# Bs at satellite 42984.030729319486 nT
# Wrote to output/Sept30_Storm/recon_event9.csv
# RR Max: 11.434921140024969 mV / m
# /home/ubuntu/tracers-work/tracers-first-results-paper/lib_dasilva2026.py:209: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(new_xticklabels)

# %% [markdown]
# # Event #10

# %%
row = df.iloc[10]

data = lib_dasilva2026.load_data(
    aci_file=row.aci_file,
    ead_file=row.ead_file,
)
subset_data = data.subset(row.start_time, row.end_time)
dispersion_stime = row.start_time + timedelta(seconds=32)
dispersion_etime = row.end_time - timedelta(seconds=29)

fig, (ax1, ax2) = subset_data.plot_recon_rate(
    dispersion_stime, 
    dispersion_etime, 
    d=get_d(row.i),
    data_file=f'output/Sept30_Storm/recon_event{row.i}.csv',
)
# Out:
# d = 12.82
# Bs at satellite 44333.744401935386 nT
# Wrote to output/Sept30_Storm/recon_event10.csv
# RR Max: 2.5255489465383585 mV / m
# /home/ubuntu/tracers-work/tracers-first-results-paper/lib_dasilva2026.py:209: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(new_xticklabels)

# %% [markdown]
# # Event #11

# %%
row = df.iloc[11]

data = lib_dasilva2026.load_data(
    aci_file=row.aci_file,
    ead_file=row.ead_file,
)
subset_data = data.subset(row.start_time, row.end_time)
dispersion_stime = row.start_time + timedelta(seconds=32)
dispersion_etime = row.end_time - timedelta(seconds=30)

fig, (ax1, ax2) = subset_data.plot_recon_rate(
    dispersion_stime, 
    dispersion_etime, 
    d=get_d(row.i),
    data_file=f'output/Sept30_Storm/recon_event{row.i}.csv',
)
# Out:
# d = 13.76
# Bs at satellite 45082.88125518224 nT
# Wrote to output/Sept30_Storm/recon_event11.csv
# RR Max: 2.2298076676357015 mV / m
# /home/ubuntu/tracers-work/tracers-first-results-paper/lib_dasilva2026.py:209: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(new_xticklabels)

# %% [markdown]
# # Event #12

# %%
row = df.iloc[12]

data = lib_dasilva2026.load_data(
    aci_file=row.aci_file,
    ead_file=row.ead_file,
)
subset_data = data.subset(row.start_time, row.end_time)
dispersion_stime = row.start_time + timedelta(seconds=30)
dispersion_etime = row.end_time - timedelta(seconds=23)

fig, (ax1, ax2) = subset_data.plot_recon_rate(
    dispersion_stime, 
    dispersion_etime, 
    d=get_d(row.i),
    data_file=f'output/Sept30_Storm/recon_event{row.i}.csv',
)
# Out:
# d = 17.21
# Bs at satellite 44412.34766111524 nT
# Wrote to output/Sept30_Storm/recon_event12.csv
# RR Max: 11.623354145216112 mV / m
# /home/ubuntu/tracers-work/tracers-first-results-paper/lib_dasilva2026.py:209: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(new_xticklabels)

# %% [markdown]
# # Event #13

# %%
row = df.iloc[13]

data = lib_dasilva2026.load_data(
    aci_file=row.aci_file,
    ead_file=row.ead_file,
)
subset_data = data.subset(row.start_time, row.end_time)
dispersion_stime = row.start_time + timedelta(seconds=25)
dispersion_etime = row.end_time - timedelta(seconds=32)

fig, (ax1, ax2) = subset_data.plot_recon_rate(
    dispersion_stime, 
    dispersion_etime, 
    d=get_d(row.i),
    data_file=f'output/Sept30_Storm/recon_event{row.i}.csv',
)
# Out:
# d = 16.84
# Bs at satellite 43987.20579846889 nT
# Wrote to output/Sept30_Storm/recon_event13.csv
# RR Max: 1.1672588268968442 mV / m
# /home/ubuntu/tracers-work/tracers-first-results-paper/lib_dasilva2026.py:209: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(new_xticklabels)

# %% [markdown]
# # Event #14

# %%
row = df.iloc[14]

data = lib_dasilva2026.load_data(
    aci_file=row.aci_file,
    ead_file=row.ead_file,
)
subset_data = data.subset(row.start_time, row.end_time)
dispersion_stime = row.start_time + timedelta(seconds=5)
dispersion_etime = row.end_time - timedelta(seconds=30)

fig, (ax1, ax2) = subset_data.plot_recon_rate(
    dispersion_stime, 
    dispersion_etime, 
    d=get_d(row.i),
    data_file=f'output/Sept30_Storm/recon_event{row.i}.csv',
)
# Out:
# d = 18.41
# Bs at satellite 43793.27584595034 nT
# Wrote to output/Sept30_Storm/recon_event14.csv
# RR Max: 1.378466089415137 mV / m
# /home/ubuntu/tracers-work/tracers-first-results-paper/lib_dasilva2026.py:209: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(new_xticklabels)

# %% [markdown]
# # Event #15

# %%
row = df.iloc[15]

data = lib_dasilva2026.load_data(
    aci_file=row.aci_file,
    ead_file=row.ead_file,
)
subset_data = data.subset(row.start_time, row.end_time)
dispersion_stime = row.start_time + timedelta(seconds=15)
dispersion_etime = row.end_time - timedelta(seconds=30)

fig, (ax1, ax2) = subset_data.plot_recon_rate(
    dispersion_stime, 
    dispersion_etime, 
    d=get_d(row.i),
    data_file=f'output/Sept30_Storm/recon_event{row.i}.csv',
)
# Out:
# d = 15.68
# Bs at satellite 43786.51881785687 nT
# Wrote to output/Sept30_Storm/recon_event15.csv
# RR Max: 1.3468646065777738 mV / m
# /home/ubuntu/tracers-work/tracers-first-results-paper/lib_dasilva2026.py:209: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(new_xticklabels)

# %% [markdown]
# # Event #16

# %%
row = df.iloc[16]

data = lib_dasilva2026.load_data(
    aci_file=row.aci_file,
    ead_file=row.ead_file,
)
subset_data = data.subset(row.start_time, row.end_time)
dispersion_stime = row.start_time + timedelta(seconds=32)
dispersion_etime = row.end_time - timedelta(seconds=30)

fig, (ax1, ax2) = subset_data.plot_recon_rate(
    dispersion_stime, 
    dispersion_etime, 
    d=get_d(row.i),
    data_file=f'output/Sept30_Storm/recon_event{row.i}.csv',
)
# Out:
# d = 15.74
# Bs at satellite 43536.84212240909 nT
# Wrote to output/Sept30_Storm/recon_event16.csv
# RR Max: 1.333699298212977 mV / m
# /home/ubuntu/tracers-work/tracers-first-results-paper/lib_dasilva2026.py:209: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(new_xticklabels)

# %% [markdown]
# # Event #17

# %%
row = df.iloc[17]

data = lib_dasilva2026.load_data(
    aci_file=row.aci_file,
    ead_file=row.ead_file,
)
subset_data = data.subset(row.start_time, row.end_time)
dispersion_stime = row.start_time + timedelta(seconds=5)
dispersion_etime = row.end_time - timedelta(seconds=28)

fig, (ax1, ax2) = subset_data.plot_recon_rate(
    dispersion_stime, 
    dispersion_etime, 
    d=get_d(row.i),
    data_file=f'output/Sept30_Storm/recon_event{row.i}.csv',
)
# Out:
# d = 13.72
# Bs at satellite 44325.49485335761 nT
# Wrote to output/Sept30_Storm/recon_event17.csv
# RR Max: 0.7770090454470233 mV / m
# /home/ubuntu/tracers-work/tracers-first-results-paper/lib_dasilva2026.py:209: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(new_xticklabels)

# %% [markdown]
# # Event #18

# %%
row = df.iloc[18]

data = lib_dasilva2026.load_data(
    aci_file=row.aci_file,
    ead_file=row.ead_file,
)
subset_data = data.subset(row.start_time, row.end_time)
dispersion_stime = row.start_time + timedelta(seconds=32)
dispersion_etime = row.end_time - timedelta(seconds=18)

fig, (ax1, ax2) = subset_data.plot_recon_rate(
    dispersion_stime, 
    dispersion_etime, 
    d=get_d(row.i),
    data_file=f'output/Sept30_Storm/recon_event{row.i}.csv',
)
# Out:
# d = 12.30
# Bs at satellite 44543.713879848525 nT
# Wrote to output/Sept30_Storm/recon_event18.csv
# RR Max: 1.4966024206426682 mV / m
# /home/ubuntu/tracers-work/tracers-first-results-paper/lib_dasilva2026.py:209: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(new_xticklabels)

# %% [markdown]
# # Event #19

# %%
row = df.iloc[10]

data = lib_dasilva2026.load_data(
    aci_file=row.aci_file,
    ead_file=row.ead_file,
)
subset_data = data.subset(row.start_time, row.end_time)
dispersion_stime = row.start_time + timedelta(seconds=32)
dispersion_etime = row.end_time - timedelta(seconds=25)

fig, (ax1, ax2) = subset_data.plot_recon_rate(
    dispersion_stime, 
    dispersion_etime, 
    d=get_d(row.i),
    data_file=f'output/Sept30_Storm/recon_event{row.i}.csv',
)
# Out:
# d = 12.82
# Bs at satellite 44320.81284660924 nT
# Wrote to output/Sept30_Storm/recon_event10.csv
# RR Max: 2.525180585391712 mV / m
# /home/ubuntu/tracers-work/tracers-first-results-paper/lib_dasilva2026.py:209: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(new_xticklabels)

# %% [markdown]
# # Event #20

# %%
row = df.iloc[20]

data = lib_dasilva2026.load_data(
    aci_file=row.aci_file,
    ead_file=row.ead_file,
)
subset_data = data.subset(row.start_time, row.end_time)
dispersion_stime = row.start_time + timedelta(seconds=25)
dispersion_etime = row.end_time - timedelta(seconds=20)

fig, (ax1, ax2) = subset_data.plot_recon_rate(
    dispersion_stime, 
    dispersion_etime, 
    d=get_d(row.i),
    data_file=f'output/Sept30_Storm/recon_event{row.i}.csv',
)
# Out:
# d = 14.99
# Bs at satellite 44337.107257620126 nT
# Wrote to output/Sept30_Storm/recon_event20.csv
# RR Max: 1.1286777701481983 mV / m
# /home/ubuntu/tracers-work/tracers-first-results-paper/lib_dasilva2026.py:209: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(new_xticklabels)
