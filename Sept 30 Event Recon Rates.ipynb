# %%
from datetime import timedelta
import pandas as pd
import numpy as np
import lib_dasilva2026

# %%
def get_d(i):
    with open(f'output/Sept30_Storm/dprime_{i}.txt', 'r') as fh:
        d = float(fh.read())
        print(f'd = {d:.2f}')
        return d

# %%
def get_alpha(i):
    df_alpha = pd.read_csv('output/Sept30_Storm/alpha.csv')
    return df_alpha.iloc[i].alpha

# %%
df = pd.read_csv('output/Sept30_Storm_filtered.csv', parse_dates=['start_time', 'end_time'], index_col=0)
df['i'] = np.arange(len(df))

# %% [markdown]
# # Event #0

# %%
row = df.iloc[0]

data = lib_dasilva2026.load_data(
    aci_file=row.aci_file,
    ead_file=row.ead_file,
)
subset_data = data.subset(row.start_time, row.end_time)
dispersion_stime = row.start_time
dispersion_etime = row.end_time - timedelta(seconds=25)

fig, (ax1, ax2) = subset_data.plot_recon_rate(
    dispersion_stime, 
    dispersion_etime, 
    d=get_d(row.i),
    alpha=get_alpha(row.i),
    data_file=f'output/Sept30_Storm/recon_event{row.i}.csv',
)
# Out:
# d = 15.79
# Bs at satellite 44699.46130975913 nT
# Wrote to output/Sept30_Storm/recon_event0.csv
# RR Max: 1.7838220133601794 mV / m
# /home/ubuntu/tracers-work/tracers-first-results-paper/lib_dasilva2026.py:209: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(new_xticklabels)

# %% [markdown]
# # Event #1

# %%
row = df.iloc[1]

data = lib_dasilva2026.load_data(
    aci_file=row.aci_file,
    ead_file=row.ead_file,
)
subset_data = data.subset(row.start_time, row.end_time)
dispersion_stime = row.start_time
dispersion_etime = row.end_time - timedelta(seconds=25)

fig, (ax1, ax2) = subset_data.plot_recon_rate(
    dispersion_stime, 
    dispersion_etime, 
    d=get_d(row.i),
    alpha=get_alpha(row.i),
    data_file=f'output/Sept30_Storm/{row.i}.csv',
)
# Out:
# d = 10.61
# Bs at satellite 44425.946531250804 nT
# Wrote to output/Sept30_Storm/1.csv
# RR Max: 2.442345512090767 mV / m
# /home/ubuntu/tracers-work/tracers-first-results-paper/lib_dasilva2026.py:209: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(new_xticklabels)

# %% [markdown]
# # Event #2

# %%
row = df.iloc[2]

data = lib_dasilva2026.load_data(
    aci_file=row.aci_file,
    ead_file=row.ead_file,
)
subset_data = data.subset(row.start_time, row.end_time)
dispersion_stime = row.start_time + timedelta(seconds=20)
dispersion_etime = row.end_time - timedelta(seconds=25)

fig, (ax1, ax2) = subset_data.plot_recon_rate(
    dispersion_stime, 
    dispersion_etime, 
    d=get_d(row.i),
    alpha=get_alpha(row.i),
    data_file=f'output/Sept30_Storm/recon_event{row.i}.csv',
)
# Out:
# d = 13.10
# Bs at satellite 45150.31320665459 nT
# Wrote to output/Sept30_Storm/recon_event2.csv
# RR Max: 1.7693236131004852 mV / m
# /home/ubuntu/tracers-work/tracers-first-results-paper/lib_dasilva2026.py:209: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(new_xticklabels)

# %% [markdown]
# # Event #3

# %%
row = df.iloc[3]

data = lib_dasilva2026.load_data(
    aci_file=row.aci_file,
    ead_file=row.ead_file,
)
subset_data = data.subset(row.start_time, row.end_time)
dispersion_stime = row.start_time + timedelta(seconds=32)
dispersion_etime = row.end_time - timedelta(seconds=17)

fig, (ax1, ax2) = subset_data.plot_recon_rate(
    dispersion_stime, 
    dispersion_etime, 
    d=get_d(row.i),
    alpha=get_alpha(row.i),
    data_file=f'output/Sept30_Storm/recon_event{row.i}.csv',
)
# Out:
# d = 9.16
# Bs at satellite 44099.84681020772 nT
# Wrote to output/Sept30_Storm/recon_event3.csv
# RR Max: 3.3124457563681786 mV / m
# /home/ubuntu/tracers-work/tracers-first-results-paper/lib_dasilva2026.py:209: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(new_xticklabels)

# %% [markdown]
# # Event #4

# %%
row = df.iloc[4]

data = lib_dasilva2026.load_data(
    aci_file=row.aci_file,
    ead_file=row.ead_file,
)
subset_data = data.subset(row.start_time, row.end_time)
dispersion_stime = row.start_time + timedelta(seconds=32)
dispersion_etime = row.end_time - timedelta(seconds=28)

fig, (ax1, ax2) = subset_data.plot_recon_rate(
    dispersion_stime, 
    dispersion_etime, 
    d=get_d(row.i),
    alpha=get_alpha(row.i),
    data_file=f'output/Sept30_Storm/recon_event{row.i}.csv',
)
# Out:
# d = 14.76
# Bs at satellite 44249.24628446715 nT
# Wrote to output/Sept30_Storm/recon_event4.csv
# RR Max: 1.8511573175728138 mV / m
# /home/ubuntu/tracers-work/tracers-first-results-paper/lib_dasilva2026.py:209: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(new_xticklabels)

# %% [markdown]
# # Event #5

# %%
row = df.iloc[5]

data = lib_dasilva2026.load_data(
    aci_file=row.aci_file,
    ead_file=row.ead_file,
)
subset_data = data.subset(row.start_time, row.end_time)
dispersion_stime = row.start_time + timedelta(seconds=15)
dispersion_etime = row.end_time - timedelta(seconds=28)

fig, (ax1, ax2) = subset_data.plot_recon_rate(
    dispersion_stime, 
    dispersion_etime, 
    d=get_d(row.i),
    alpha=get_alpha(row.i),
    data_file=f'output/Sept30_Storm/recon_event{row.i}.csv',
)
# Out:
# d = 14.52
# Bs at satellite 43696.286004719375 nT
# Wrote to output/Sept30_Storm/recon_event5.csv
# RR Max: 0.5076814330576195 mV / m
# /home/ubuntu/tracers-work/tracers-first-results-paper/lib_dasilva2026.py:209: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(new_xticklabels)

# %% [markdown]
# # Event #6

# %%
row = df.iloc[6]

data = lib_dasilva2026.load_data(
    aci_file=row.aci_file,
    ead_file=row.ead_file,
)
subset_data = data.subset(row.start_time, row.end_time)
dispersion_stime = row.start_time + timedelta(seconds=5)
dispersion_etime = row.end_time - timedelta(seconds=27)

fig, (ax1, ax2) = subset_data.plot_recon_rate(
    dispersion_stime, 
    dispersion_etime, 
    d=get_d(row.i),
    alpha=get_alpha(row.i),
    data_file=f'output/Sept30_Storm/recon_event{row.i}.csv',
)
# Out:
# d = 15.78
# Bs at satellite 44455.502752662316 nT
# Wrote to output/Sept30_Storm/recon_event6.csv
# RR Max: 0.6806382155739829 mV / m
# /home/ubuntu/tracers-work/tracers-first-results-paper/lib_dasilva2026.py:209: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(new_xticklabels)

# %% [markdown]
# # Event #7

# %%
row = df.iloc[7]

data = lib_dasilva2026.load_data(
    aci_file=row.aci_file,
    ead_file=row.ead_file,
)
subset_data = data.subset(row.start_time, row.end_time)
dispersion_stime = row.start_time + timedelta(seconds=17)
dispersion_etime = row.end_time - timedelta(seconds=24)

fig, (ax1, ax2) = subset_data.plot_recon_rate(
    dispersion_stime, 
    dispersion_etime, 
    d=get_d(row.i),
    alpha=get_alpha(row.i),
    data_file=f'output/Sept30_Storm/recon_event{row.i}.csv',
)
# Out:
# d = 22.64
# Bs at satellite 44427.82376191566 nT
# Wrote to output/Sept30_Storm/recon_event7.csv
# RR Max: 1.7351366707779479 mV / m
# /home/ubuntu/tracers-work/tracers-first-results-paper/lib_dasilva2026.py:209: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(new_xticklabels)

# %% [markdown]
# # Event #8

# %%
row = df.iloc[8]

data = lib_dasilva2026.load_data(
    aci_file=row.aci_file,
    ead_file=row.ead_file,
)
subset_data = data.subset(row.start_time, row.end_time)
dispersion_stime = row.start_time + timedelta(seconds=25)
dispersion_etime = row.end_time - timedelta(seconds=25)

fig, (ax1, ax2) = subset_data.plot_recon_rate(
    dispersion_stime, 
    dispersion_etime, 
    d=get_d(row.i),
    alpha=get_alpha(row.i),
    data_file=f'output/Sept30_Storm/recon_event{row.i}.csv',
)
# Out:
# d = 14.28
# Bs at satellite 43049.64326986204 nT
# Wrote to output/Sept30_Storm/recon_event8.csv
# RR Max: 0.9259096505476141 mV / m
# /home/ubuntu/tracers-work/tracers-first-results-paper/lib_dasilva2026.py:209: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(new_xticklabels)

# %% [markdown]
# # Event #9

# %%
row = df.iloc[9]

data = lib_dasilva2026.load_data(
    aci_file=row.aci_file,
    ead_file=row.ead_file,
)
subset_data = data.subset(row.start_time, row.end_time)
dispersion_stime = row.start_time + timedelta(seconds=32)
dispersion_etime = row.end_time - timedelta(seconds=33)

fig, (ax1, ax2) = subset_data.plot_recon_rate(
    dispersion_stime, 
    dispersion_etime, 
    d=get_d(row.i),
    alpha=get_alpha(row.i),
    data_file=f'output/Sept30_Storm/recon_event{row.i}.csv',
)
# Out:
# d = 14.55
# Bs at satellite 42984.03072931949 nT
# Wrote to output/Sept30_Storm/recon_event9.csv
# RR Max: 7.60685664542346 mV / m
# /home/ubuntu/tracers-work/tracers-first-results-paper/lib_dasilva2026.py:209: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(new_xticklabels)

# %% [markdown]
# # Event #10

# %%
row = df.iloc[10]

data = lib_dasilva2026.load_data(
    aci_file=row.aci_file,
    ead_file=row.ead_file,
)
subset_data = data.subset(row.start_time, row.end_time)
dispersion_stime = row.start_time + timedelta(seconds=32)
dispersion_etime = row.end_time - timedelta(seconds=29)

fig, (ax1, ax2) = subset_data.plot_recon_rate(
    dispersion_stime, 
    dispersion_etime, 
    d=get_d(row.i),
    alpha=get_alpha(row.i),
    data_file=f'output/Sept30_Storm/recon_event{row.i}.csv',
)
# Out:
# d = 12.82
# Bs at satellite 44333.74440193539 nT
# Wrote to output/Sept30_Storm/recon_event10.csv
# RR Max: 1.757561830316282 mV / m
# /home/ubuntu/tracers-work/tracers-first-results-paper/lib_dasilva2026.py:209: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(new_xticklabels)

# %% [markdown]
# # Event #11

# %%
row = df.iloc[11]

data = lib_dasilva2026.load_data(
    aci_file=row.aci_file,
    ead_file=row.ead_file,
)
subset_data = data.subset(row.start_time, row.end_time)
dispersion_stime = row.start_time + timedelta(seconds=32)
dispersion_etime = row.end_time - timedelta(seconds=30)

fig, (ax1, ax2) = subset_data.plot_recon_rate(
    dispersion_stime, 
    dispersion_etime, 
    d=get_d(row.i),
    alpha=get_alpha(row.i),
    data_file=f'output/Sept30_Storm/recon_event{row.i}.csv',
)
# Out:
# d = 13.76
# Bs at satellite 45082.88125518225 nT
# Wrote to output/Sept30_Storm/recon_event11.csv
# RR Max: 1.9349500616314073 mV / m
# /home/ubuntu/tracers-work/tracers-first-results-paper/lib_dasilva2026.py:209: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(new_xticklabels)

# %% [markdown]
# # Event #12

# %%
row = df.iloc[12]

data = lib_dasilva2026.load_data(
    aci_file=row.aci_file,
    ead_file=row.ead_file,
)
subset_data = data.subset(row.start_time, row.end_time)
dispersion_stime = row.start_time + timedelta(seconds=30)
dispersion_etime = row.end_time - timedelta(seconds=23)

fig, (ax1, ax2) = subset_data.plot_recon_rate(
    dispersion_stime, 
    dispersion_etime, 
    d=get_d(row.i),
    alpha=get_alpha(row.i),
    data_file=f'output/Sept30_Storm/recon_event{row.i}.csv',
)
# Out:
# d = 17.21
# Bs at satellite 44412.347661115244 nT
# Wrote to output/Sept30_Storm/recon_event12.csv
# RR Max: 11.54863754724853 mV / m
# /home/ubuntu/tracers-work/tracers-first-results-paper/lib_dasilva2026.py:209: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(new_xticklabels)

# %% [markdown]
# # Event #13

# %%
row = df.iloc[13]

data = lib_dasilva2026.load_data(
    aci_file=row.aci_file,
    ead_file=row.ead_file,
)
subset_data = data.subset(row.start_time, row.end_time)
dispersion_stime = row.start_time + timedelta(seconds=25)
dispersion_etime = row.end_time - timedelta(seconds=32)

fig, (ax1, ax2) = subset_data.plot_recon_rate(
    dispersion_stime, 
    dispersion_etime, 
    d=get_d(row.i),
    alpha=get_alpha(row.i),
    data_file=f'output/Sept30_Storm/recon_event{row.i}.csv',
)
# Out:
# d = 16.84
# Bs at satellite 43987.205798468894 nT
# Wrote to output/Sept30_Storm/recon_event13.csv
# RR Max: 1.1354812304322472 mV / m
# /home/ubuntu/tracers-work/tracers-first-results-paper/lib_dasilva2026.py:209: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(new_xticklabels)

# %% [markdown]
# # Event #14

# %%
row = df.iloc[14]

data = lib_dasilva2026.load_data(
    aci_file=row.aci_file,
    ead_file=row.ead_file,
)
subset_data = data.subset(row.start_time, row.end_time)
dispersion_stime = row.start_time + timedelta(seconds=5)
dispersion_etime = row.end_time - timedelta(seconds=30)

fig, (ax1, ax2) = subset_data.plot_recon_rate(
    dispersion_stime, 
    dispersion_etime, 
    d=get_d(row.i),
    alpha=get_alpha(row.i),
    data_file=f'output/Sept30_Storm/recon_event{row.i}.csv',
)
# Out:
# d = 18.41
# Bs at satellite 43793.275845950346 nT
# Wrote to output/Sept30_Storm/recon_event14.csv
# RR Max: 1.2553465446057523 mV / m
# /home/ubuntu/tracers-work/tracers-first-results-paper/lib_dasilva2026.py:209: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(new_xticklabels)

# %% [markdown]
# # Event #15

# %%
row = df.iloc[15]

data = lib_dasilva2026.load_data(
    aci_file=row.aci_file,
    ead_file=row.ead_file,
)
subset_data = data.subset(row.start_time, row.end_time)
dispersion_stime = row.start_time + timedelta(seconds=15)
dispersion_etime = row.end_time - timedelta(seconds=30)

fig, (ax1, ax2) = subset_data.plot_recon_rate(
    dispersion_stime, 
    dispersion_etime, 
    d=get_d(row.i),
    alpha=get_alpha(row.i),
    data_file=f'output/Sept30_Storm/recon_event{row.i}.csv',
)
# Out:
# d = 15.68
# Bs at satellite 43786.51881785688 nT
# Wrote to output/Sept30_Storm/recon_event15.csv
# RR Max: 0.7840408251807828 mV / m
# /home/ubuntu/tracers-work/tracers-first-results-paper/lib_dasilva2026.py:209: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(new_xticklabels)

# %% [markdown]
# # Event #16

# %%
row = df.iloc[16]

data = lib_dasilva2026.load_data(
    aci_file=row.aci_file,
    ead_file=row.ead_file,
)
subset_data = data.subset(row.start_time, row.end_time)
dispersion_stime = row.start_time + timedelta(seconds=32)
dispersion_etime = row.end_time - timedelta(seconds=30)

fig, (ax1, ax2) = subset_data.plot_recon_rate(
    dispersion_stime, 
    dispersion_etime, 
    d=get_d(row.i),
    alpha=get_alpha(row.i),
    data_file=f'output/Sept30_Storm/recon_event{row.i}.csv',
)
# Out:
# d = 15.74
# Bs at satellite 43536.8421224091 nT
# Wrote to output/Sept30_Storm/recon_event16.csv
# RR Max: 0.944712344469498 mV / m
# /home/ubuntu/tracers-work/tracers-first-results-paper/lib_dasilva2026.py:209: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(new_xticklabels)

# %% [markdown]
# # Event #17

# %%
row = df.iloc[17]

data = lib_dasilva2026.load_data(
    aci_file=row.aci_file,
    ead_file=row.ead_file,
)
subset_data = data.subset(row.start_time, row.end_time)
dispersion_stime = row.start_time + timedelta(seconds=5)
dispersion_etime = row.end_time - timedelta(seconds=28)

fig, (ax1, ax2) = subset_data.plot_recon_rate(
    dispersion_stime, 
    dispersion_etime, 
    d=get_d(row.i),
    alpha=get_alpha(row.i),
    data_file=f'output/Sept30_Storm/recon_event{row.i}.csv',
)
# Out:
# d = 13.72
# Bs at satellite 44325.49485335761 nT
# Wrote to output/Sept30_Storm/recon_event17.csv
# RR Max: 0.6309962460534545 mV / m
# /home/ubuntu/tracers-work/tracers-first-results-paper/lib_dasilva2026.py:209: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(new_xticklabels)

# %% [markdown]
# # Event #18

# %%
row = df.iloc[18]

data = lib_dasilva2026.load_data(
    aci_file=row.aci_file,
    ead_file=row.ead_file,
)
subset_data = data.subset(row.start_time, row.end_time)
dispersion_stime = row.start_time + timedelta(seconds=32)
dispersion_etime = row.end_time - timedelta(seconds=18)

fig, (ax1, ax2) = subset_data.plot_recon_rate(
    dispersion_stime, 
    dispersion_etime, 
    d=get_d(row.i),
    alpha=get_alpha(row.i),
    data_file=f'output/Sept30_Storm/recon_event{row.i}.csv',
)
# Out:
# d = 12.30
# Bs at satellite 44543.71387984853 nT
# Wrote to output/Sept30_Storm/recon_event18.csv
# RR Max: 1.3358460965267684 mV / m
# /home/ubuntu/tracers-work/tracers-first-results-paper/lib_dasilva2026.py:209: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(new_xticklabels)

# %% [markdown]
# # Event #19

# %%
row = df.iloc[10]

data = lib_dasilva2026.load_data(
    aci_file=row.aci_file,
    ead_file=row.ead_file,
)
subset_data = data.subset(row.start_time, row.end_time)
dispersion_stime = row.start_time + timedelta(seconds=32)
dispersion_etime = row.end_time - timedelta(seconds=25)

fig, (ax1, ax2) = subset_data.plot_recon_rate(
    dispersion_stime, 
    dispersion_etime, 
    d=get_d(row.i),
    alpha=get_alpha(row.i),
    data_file=f'output/Sept30_Storm/recon_event{row.i}.csv',
)
# Out:
# d = 12.82
# Bs at satellite 44320.812846609246 nT
# Wrote to output/Sept30_Storm/recon_event10.csv
# RR Max: 1.757305483080564 mV / m
# /home/ubuntu/tracers-work/tracers-first-results-paper/lib_dasilva2026.py:209: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(new_xticklabels)

# %% [markdown]
# # Event #20

# %%
row = df.iloc[20]

data = lib_dasilva2026.load_data(
    aci_file=row.aci_file,
    ead_file=row.ead_file,
)
subset_data = data.subset(row.start_time, row.end_time)
dispersion_stime = row.start_time + timedelta(seconds=25)
dispersion_etime = row.end_time - timedelta(seconds=20)

fig, (ax1, ax2) = subset_data.plot_recon_rate(
    dispersion_stime, 
    dispersion_etime, 
    d=get_d(row.i),
    alpha=get_alpha(row.i),
    data_file=f'output/Sept30_Storm/recon_event{row.i}.csv',
)
# Out:
# d = 14.99
# Bs at satellite 44337.10725762013 nT
# Wrote to output/Sept30_Storm/recon_event20.csv
# RR Max: 1.1202647772037029 mV / m
# /home/ubuntu/tracers-work/tracers-first-results-paper/lib_dasilva2026.py:209: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(new_xticklabels)
