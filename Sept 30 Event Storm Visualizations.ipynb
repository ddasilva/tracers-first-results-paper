# %%
start_time = "2025-09-27T00:00:00"
end_time = "2025-10-8T00:00:00"
storm = "Sept30_Storm"
title = 'Sept 30, 2025 Storm'

# %%
import lib_stormvis
import pylab as plt

# %%
lib_stormvis.make_storm_vis(storm, start_time, end_time, title,
                           hl={3: ('red', 'Figure 2 (Near Dst Minimum)'), 
                               12: ('orange', 'Figure 4 (Recovery Period)')})
# Out:
# 3 2025-09-30 11:28:56 0.0004354584853270913
# 4 2025-10-01 16:29:31 0.7024283701100853
# 5 2025-10-02 11:47:46 0.49865406654533456
# 6 2025-10-02 13:24:18 0.2755092863392937
# 7 2025-10-03 23:09:40 0.192053335105235
# 8 2025-10-04 05:36:14 0.18882624179449908
# 9 2025-10-04 07:13:06 0.1634926883775062
# 10 2025-10-04 12:03:55 0.15777622700207933
# 11 2025-10-06 15:34:51 0.15133723861425208
# 12 2025-10-06 23:35:33 0.14401494309300794
# 13 2025-10-07 01:12:04 0.1346864020036037
# 14 2025-10-07 02:48:39 0.09067828594523618
# 15 2025-10-07 06:01:02 0.0655083387980624
# 16 2025-10-07 07:38:22 0.0402779448028659
# 17 2025-10-07 12:30:54 0.021835693463643644
# 18 2025-10-07 14:07:42 0.0009395202291405578
# 19 2025-10-07 20:33:28 1.0442230503505234e-05
# 20 2025-10-07 23:44:21 0.007532760390676038
# SYM-H Minimum: -129
# 4
# ...
