# %%
start_time = "2025-09-27T00:00:00"
end_time = "2025-10-8T00:00:00"
storm = "Sept30_Storm"
title = 'Sept 30, 2025 Storm'

# %%
import lib_stormvis
import pylab as plt

# %%
lib_stormvis.make_storm_vis(storm, start_time, end_time, title,
                           hl={3: ('red', 'Figure 2 (Near Dst Minimum)'), 
                               12: ('orange', 'Figure 4 (Recovery Period)')})
# Out:
# 3 2025-09-30 11:28:56 0.00017826517421850064
# 4 2025-10-01 16:29:31 0.6163747160100305
# 5 2025-10-02 11:47:46 0.4758651515483846
# 6 2025-10-02 13:24:18 0.15587742822359918
# 7 2025-10-03 23:09:40 0.1283824462553871
# 8 2025-10-04 05:36:14 0.12861601176065265
# 9 2025-10-04 07:13:06 0.07013596910321268
# 10 2025-10-04 12:03:55 0.04314934782113091
# 11 2025-10-06 15:34:51 0.04442350121922586
# 12 2025-10-06 23:35:33 0.047911855457100604
# 13 2025-10-07 01:12:04 0.0495338613986658
# 14 2025-10-07 02:48:39 0.04252882499611418
# 15 2025-10-07 06:01:02 0.03816375063519583
# 16 2025-10-07 07:38:22 0.01869338110861135
# 17 2025-10-07 12:30:54 0.00616648726063001
# 18 2025-10-07 14:07:42 0.0034572013284192684
# 19 2025-10-07 20:33:28 0.005104696001510508
# 20 2025-10-07 23:44:21 0.01375524730672394
# SYM-H Minimum: -129
# 4
# /home/ubuntu/tracers-work/tracers-first-results-paper/lib_stormvis.py:201: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "ko" (-> color='k'). The keyword argument will take precedence.
#   ax.plot(x[:i+1], y[:i+1], 'ko', color='#000000', label='Onset and Main Phase')
